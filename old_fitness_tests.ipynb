# %% [markdown]
# ### Testing Librosa waveform

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import maximum_filter
import numpy as np
import matplotlib.pyplot as plt

from statistics import NormalDist

from sklearn.decomposition import PCA

from librosa import load as load_audio
from librosa import stft, amplitude_to_db
from librosa.display import specshow

from scipy.ndimage import label as label_features
from scipy.ndimage import maximum_position as extract_region_maximums
from scipy.spatial.distance import cdist

# %%
def display_wave_form(filepath):
    # Load the audio file
    y, sr = librosa.load(filepath)

    # Plot the waveform
    plt.figure(figsize=(14, 5))
    librosa.display.waveshow(y, sr=sr)
    plt.title('Waveform')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.show()

# %%
display_wave_form("audios/scala.mp3")
display_wave_form("audios/scala_Reverb_low.mp3")

# %% [markdown]
# ### Spectrogram

# %%
def plot_spectrogram(file_path):
    # Load the MP3 file using librosa
    y, sr = librosa.load(file_path, sr=None)
    
    # Print audio information
    print(f"Audio File: {file_path}")
    print(f"Sample Rate (Hz): {sr}")
    print(f"Audio Length (seconds): {len(y) / sr:.2f}")

    # Compute the Short-Time Fourier Transform (STFT)  
    N_FFT = 2048  # FFT window size
    N_O = N_FFT // 4
    D = librosa.stft(y, n_fft=N_FFT)
    print(f"D shape: {D.shape}")
    
    frame_rate = sr / N_O
    print(f"Frame Rate (Hz): {frame_rate:.2f}")
  
    # Convert the complex-valued STFT result to magnitude
    S_db = librosa.amplitude_to_db(abs(D), ref=np.max)

    # Plot the spectrogram
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='hz', cmap='inferno')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Spectrogram')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')
    plt.show()

# %%
# Plot spectrogram for the first MP3 file
#plot_spectrogram('D5_acoustic_guitar.mp3')

# Plot spectrogram for the second MP3 file
#plot_spectrogram('D5_acoustic_guitar_with_reverb.mp3')

# %% [markdown]
# ### Constellation Map tests

# %%
from matplotlib.patches import Rectangle

def constellation_map_builder(file_path): 
    #step 1: Set parameters
    N_FFT = 2048  # FFT window size
    N_O = N_FFT // 4

    #step 2: Load audio file
    y, sr = librosa.load(file_path, sr=None)

    #step 3: Compute the spectrogram
    D = librosa.stft(y, n_fft=N_FFT, hop_length=N_O)
    S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
    
    #step 4: Define window lengths for peak detection  
    d_t = 30
    d_f = 30

    #step 5: Select settings for peak detection
    #using maximum filter to detect local maxima
    local_max = maximum_filter(S_db, size=(d_t, d_f))

    #step 6: Create an identification matrix
    peaks = (S_db == local_max)  # Peaks are where the original value is equal to the local max

    #step 6.5: Apply an amplitude threshold to filter out insignificant peaks
    amplitude_threshold = -30  # dB, adjust as needed
    peaks &= (S_db > amplitude_threshold)

    #step 7: Extract peaks (time, frequency, amplitude)
    times = librosa.frames_to_time(np.arange(S_db.shape[1]), sr=sr, hop_length=N_O)
    frequencies = librosa.fft_frequencies(sr=sr, n_fft=N_FFT)

    peak_indices = np.where(peaks)
    peak_times = times[peak_indices[1]]
    peak_freqs = frequencies[peak_indices[0]]
    peak_ampls = S_db[peak_indices]

    #normalize amplitudes for color mapping
    norm_ampls = (peak_ampls - np.min(peak_ampls)) / (np.max(peak_ampls) - np.min(peak_ampls))

    #save the peaks to a file (optional)
    peak_data = np.vstack((peak_times, peak_freqs, peak_ampls)).T
    peak_data_filtered = np.array([[round(x, 1), round(y, 1)] for x, y, _ in peak_data])
    np.savetxt('peaks.csv', peak_data_filtered, delimiter=',', header='Time,Frequency', comments='')
    #plots
    fig, ax = plt.subplots(1, 2, figsize=(12, 7), sharex=True)

    #plot the spectrogram with peaks

    librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='hz', cmap='inferno', ax=ax[0])
    
    # Add rectangles to indicate the windows for local maxima detection
    #num_frames = S_db.shape[1]
    #num_bins = S_db.shape[0]
    #frame_time = librosa.frames_to_time(np.arange(num_frames), sr=sr, hop_length=N_O)
    #bin_freq = librosa.fft_frequencies(sr=sr, n_fft=N_FFT)
    
    #for i in range(0, num_frames, d_t):
    #    for j in range(0, num_bins, d_f):
    #        rect = Rectangle((frame_time[i], bin_freq[j]), frame_time[min(i+d_t, num_frames-1)] - frame_time[i], bin_freq[min(j+d_f, num_bins-1)] - bin_freq[j], 
    #                         linewidth=1, edgecolor='green', facecolor='none', alpha=0.3)
    #        ax[0].add_patch(rect)
            
    sc = ax[1].scatter(peak_times, peak_freqs, c=norm_ampls, cmap='inferno', marker='x')
    ax[0].set_title('Spectrogram')
    ax[1].set_title('Constellation Map')
    ax[0].set_xlabel('Time (s)')
    ax[1].set_xlabel('Time (s)')
    ax[0].set_ylabel('Hz')
    ax[1].set_ylabel('Hz')
    fig.colorbar(sc, ax=ax[1], format="%1.1f dB", norm=norm_ampls)

    plt.show()
    
    return peak_data_filtered

# %%
print(constellation_map_builder('audios/G4_guitar.mp3'))
print(constellation_map_builder('audios/G4_guitar_Reverb_high.mp3'))
# Out:
# [[0.00000e+00 1.87500e+02]
#  [0.00000e+00 5.85900e+02]
#  [0.00000e+00 9.84400e+02]
#  [0.00000e+00 1.57030e+03]
#  [0.00000e+00 1.96880e+03]
#  [0.00000e+00 2.55470e+03]
#  [0.00000e+00 2.95310e+03]
#  [0.00000e+00 3.75000e+03]
#  [0.00000e+00 4.14840e+03]
#  [0.00000e+00 4.73440e+03]
#  [0.00000e+00 5.15620e+03]
#  [0.00000e+00 5.74220e+03]
#  [1.00000e-01 6.16410e+03]
#  [0.00000e+00 6.56250e+03]
#  [0.00000e+00 7.19530e+03]
#  [0.00000e+00 7.59380e+03]
#  [0.00000e+00 8.46090e+03]
#  [0.00000e+00 9.72660e+03]
#  [0.00000e+00 1.01719e+04]]
# [[2.0000e-01 1.8750e+02]
#  [1.0000e-01 5.8590e+02]
#  [2.0000e-01 9.8440e+02]
#  [3.0000e-01 1.5703e+03]
#  [2.0000e-01 1.9688e+03]
#  [3.0000e-01 2.5547e+03]
#  [1.0000e-01 2.9531e+03]
#  [2.0000e-01 4.1484e+03]
#  [2.0000e-01 4.7344e+03]
#  [1.0000e-01 5.1562e+03]
#  [1.0000e-01 5.7422e+03]
#  [2.0000e-01 6.1641e+03]
#  [1.0000e-01 6.5625e+03]
#  [1.0000e-01 7.1953e+03]
#  [1.0000e-01 8.4375e+03]]

# %% [markdown]
# ### Other constellation map alg [USED NOW]

# %%
def z_score_peaks_calculation(file_path, threshold):
    y, _ = librosa.load(path=file_path, sr=None)

    #do transformations
    x = librosa.stft(y)
    x = librosa.amplitude_to_db(abs(x))
    
    #remove zero values
    flattened = np.matrix.flatten(x)
    filtered = flattened[flattened > np.min(flattened)]

    #create a normal distribution from frequency intensities
    #then map a zscore onto each intensity value
    ndist = NormalDist(np.mean(filtered), np.std(filtered))
    zscore = np.vectorize(lambda x: ndist.zscore(x))
    zscore_matrix = zscore(x)

    #create label matrix from frequency intensities that are
    #above threshold
    mask_matrix = zscore_matrix > threshold
    labelled_matrix, num_regions = label_features(mask_matrix)
    label_indices = np.arange(num_regions) + 1

    #for each isolated region in the mask, identify the maximum
    #value, then extract it position
    peak_positions = extract_region_maximums(zscore_matrix, labelled_matrix, label_indices)

    #finally, create list of peaks (time, frequency, intensity)
    peaks = [[x, y] for y, x in peak_positions]

    return peaks

# %%
print(z_score_peaks_calculation('audios/G4_guitar.mp3', 1.5))
print(z_score_peaks_calculation('audios/G4_guitar_Reverb_high.mp3', 1.5))
# Out:
# [[4, 8], [27, 0], [55, 0], [76, 0], [82, 0], [89, 0], [104, 0], [117, 0], [135, 0], [154, 0], [166, 0], [174, 2], [197, 0], [215, 0], [225, 0], [231, 0], [245, 0], [255, 0], [273, 0], [288, 2], [294, 0], [312, 0], [333, 0], [337, 0], [346, 0], [362, 0], [370, 0], [376, 0], [386, 2], [410, 0], [429, 0], [437, 0], [464, 0], [483, 0], [512, 0], [284, 2], [319, 2], [68, 2], [71, 2], [88, 2], [94, 2], [108, 2], [111, 2], [121, 2], [147, 2], [181, 2], [249, 2], [253, 2], [263, 2], [266, 3], [269, 2], [276, 3], [281, 2], [296, 2], [300, 2], [315, 2], [322, 2], [335, 2], [349, 2], [355, 2], [361, 2], [380, 2], [382, 2], [451, 3], [485, 3], [110, 3], [172, 3], [180, 3], [283, 3], [318, 3], [348, 3], [384, 3], [429, 3], [458, 3], [80, 5], [510, 8], [90, 12], [93, 12], [104, 12], [115, 12], [89, 13], [172, 13], [179, 13], [40, 21], [47, 21], [59, 21], [54, 22], [78, 22], [86, 22], [311, 25], [83, 28], [41, 31], [384, 33], [95, 37], [35, 38], [46, 39], [48, 39], [53, 39], [62, 39], [229, 42], [234, 42], [20, 53], [22, 53], [37, 53], [18, 55], [66, 56], [99, 58], [107, 57], [112, 58], [142, 59], [152, 59], [166, 59], [181, 59], [186, 59], [196, 59], [102, 59], [111, 59], [201, 59], [115, 60], [40, 63], [113, 64], [57, 72], [71, 81], [79, 81], [128, 84], [29, 87], [37, 95], [56, 101], [51, 98], [145, 109], [77, 120], [69, 125], [95, 126], [68, 126], [137, 126], [29, 131], [122, 134], [17, 143], [24, 143], [32, 142], [35, 143], [42, 143], [28, 143], [31, 143], [61, 143], [30, 157], [32, 157], [39, 157], [51, 157], [17, 171], [19, 174], [72, 185], [80, 185], [35, 194], [87, 211], [16, 231], [40, 237], [38, 246], [34, 254], [40, 254], [17, 277], [26, 277], [18, 278], [19, 289], [12, 336], [11, 337], [12, 369], [7, 455], [3, 508], [5, 500], [5, 513], [3, 528], [4, 547], [3, 567], [3, 587], [3, 596], [3, 620], [3, 631], [3, 636], [4, 647], [3, 651], [3, 657], [3, 678]]
# [[18, 8], [49, 0], [58, 0], [93, 0], [96, 0], [101, 0], [99, 2], [108, 0], [121, 0], [125, 0], [157, 0], [225, 0], [180, 0], [182, 0], [214, 0], [242, 0], [253, 2], [263, 2], [286, 2], [303, 0], [306, 0], [346, 0], [452, 0], [357, 0], [364, 0], [480, 0], [112, 2], [59, 2], [88, 2], [94, 2], [116, 2], [89, 3], [144, 3], [498, 8], [502, 8], [509, 8], [514, 8], [518, 8], [92, 12], [165, 13], [178, 13], [339, 14], [89, 20], [100, 21], [97, 22], [101, 22], [285, 25], [113, 28], [133, 28], [138, 29], [391, 33], [201, 42], [55, 46], [179, 50], [188, 50], [197, 50], [205, 50], [142, 59], [127, 59], [80, 61], [106, 63], [107, 64], [277, 67], [56, 73], [38, 78], [68, 78], [76, 78], [78, 78], [93, 79], [134, 83], [141, 83], [128, 84], [111, 86], [158, 92], [48, 98], [72, 103], [168, 109], [182, 117], [111, 126], [97, 126], [101, 126], [135, 126], [145, 126], [51, 129], [43, 132], [33, 139], [34, 141], [42, 143], [49, 143], [56, 143], [68, 143], [75, 143], [25, 147], [40, 148], [59, 154], [64, 154], [28, 156], [52, 157], [43, 163], [47, 171], [27, 173], [37, 173], [44, 180], [91, 185], [95, 185], [99, 185], [71, 194], [76, 194], [24, 223], [21, 224], [23, 226], [64, 228], [28, 230], [54, 237], [26, 249], [30, 250], [32, 249], [28, 259], [22, 260], [34, 272], [42, 271], [34, 277], [30, 285], [30, 289], [26, 290], [24, 291], [11, 294], [14, 294], [27, 310], [29, 320], [31, 321], [36, 321], [29, 325], [29, 327], [18, 337], [15, 341], [7, 348], [13, 348], [31, 351], [21, 355], [31, 360], [20, 363], [13, 370], [7, 365], [27, 378], [22, 386], [23, 387], [26, 388], [7, 390], [27, 390], [12, 406], [8, 399], [5, 399], [7, 400], [19, 405], [3, 410], [4, 415], [8, 412], [33, 415], [17, 418], [16, 419], [22, 421], [8, 422], [16, 433], [27, 433], [28, 434], [11, 438], [9, 443], [14, 446], [10, 447], [13, 447], [4, 452], [12, 452], [6, 457], [11, 461], [18, 461], [23, 461], [12, 480], [14, 467], [22, 471], [15, 477], [10, 483], [3, 485], [8, 490], [18, 490], [8, 493], [3, 496], [3, 502], [3, 508], [16, 505], [14, 509], [3, 518], [10, 518], [18, 518], [7, 522], [11, 523], [4, 528], [16, 528], [4, 537], [17, 538], [8, 544], [4, 547], [3, 556], [12, 557], [8, 567], [8, 570], [8, 574], [3, 577], [12, 576], [8, 577], [3, 587], [14, 586], [8, 597], [19, 597], [3, 619], [7, 619], [8, 623], [3, 625], [4, 647], [9, 652], [10, 654], [3, 657], [7, 658], [3, 673], [3, 678], [9, 678], [9, 683], [3, 686]]

# %%
def add_epsilon_to_zeros(D, epsilon):
  D_copy = D.copy()  # Create a copy to avoid modifying the original array
  D_copy[D_copy == 0.0] = epsilon
  return D_copy

# Initialize membership matrix U based on initial distances and neighborhood function
def initialize_membership(X, Y, epsilon):
    n, m = len(X), len(Y)
    D = cdist(X, Y, metric='euclidean')
    D = add_epsilon_to_zeros(D, epsilon)
    U = np.zeros((n, m))
    for i in range(n):
        for j in range(m):
            U[i, j] = 1.0 / np.sum([(D[i, j] / (D[i, k])) ** 2 for k in range(m)])
    return U

# Update membership matrix using FOCM
def update_membership(U, D, gamma, n_clusters):
    n, m = U.shape
    for i in range(n):
        for j in range(m):
            denominator = np.sum([(D[i, j] / (D[i, k])) ** (2 / (gamma - 1)) for k in range(n_clusters)])
            U[i, j] = 1.0 / denominator
    return U

# Calculate new cluster centers
def calculate_cluster_centers(U, X, gamma):
  U_gamma = np.power(U.T, gamma)
  return (U_gamma @ X) / np.sum(U_gamma, axis=1, keepdims=True)

# %%
# FOCM algorithm
def focm(X, Y, n_clusters, max_iter=50, epsilon=1e-4, gamma=5):
    #start = time.time()

    U = initialize_membership(X, Y, epsilon)
    V = np.copy(Y)
    prev_U = np.zeros_like(U)

    for _ in range(max_iter):
        # Calculate distances
        D = cdist(X, V, metric='euclidean')
        D = add_epsilon_to_zeros(D, epsilon)

        # Update membership matrix
        U = update_membership(U, D, gamma, n_clusters)
        
        # Calculate new cluster centers
        V = calculate_cluster_centers(U, X, gamma)
        
        # Check for convergence
        if np.linalg.norm(U - prev_U) < epsilon:
            break
        prev_U = np.copy(U)
        
    #end = time.time()
    #print(f"Elapsed time FOCM: {round(end - start, 2)}")
    return U

# %%
from copy import deepcopy

# Calculate dissimilarity
def calculate_dissimilarity(file_path, output_file_path, threshold):
    #M_A = constellation_map_builder(file_path)
    #M_B = constellation_map_builder(output_file_path)
    peaks_1 = z_score_peaks_calculation(file_path, threshold)
    peaks_2 = z_score_peaks_calculation(output_file_path, threshold)
    
    M_A = None
    M_B = None
    
    if len(peaks_1) > len(peaks_2):
        n_clusters = len(peaks_2)
        M_A = deepcopy(peaks_1)
        M_B = deepcopy(peaks_2)
    else:
        n_clusters = len(peaks_1)
        M_A = deepcopy(peaks_2)
        M_B = deepcopy(peaks_1)        
        
    n_clusters = len(M_B)
    U = focm(M_A, M_B, n_clusters)

    total_distance = 0

    for i in range(len(M_A)):
        for j in range(len(M_B)):
            total_distance += U[i, j] * euclidean_distance(M_A[i], M_B[j])

    return total_distance / (len(M_A) * len(M_B))

# %%
file_path = 'audios/G4_guitar.mp3'

notes = ["audios/G4_guitar.mp3" ]

for note in notes: 
    dissimilarity = calculate_dissimilarity(file_path, note, threshold=3.5)
    print(f"Dissimilarity between G4 and {note[7:10]}: {dissimilarity}")
# Out:
# Dissimilarity between G4 and G4_: 2.1142427442675657e-05

# %%
import matplotlib.pyplot as plt
import numpy as np

effects = ['Reverb', 'Chorus', "Distortion", 'Delay', 'Phaser', 'Compressor', 'Gain', "Clipping"]
intensities = ["low", "medium", "high"]

# Initialize dissimilarities as a list of lists
dissimilarities = {effect: [] for effect in effects}

file_path = 'audios/G4_guitar.mp3'
threshold = 3

for effect in effects:
    for intensity in intensities: 
        file_tested = 'audios/G4_guitar_' + str(effect) + "_" + str(intensity) + ".mp3"
        
        dissimilarity = calculate_dissimilarity(file_path, file_tested, threshold)
        dissimilarities[effect].append(dissimilarity)
        print(f"{effect} applied, intensity: {intensity}")
        print(f"Dissimilarity: {dissimilarity}")
    

# Apply logarithmic transformation to the data
#transformed_data = {key: [np.log10(value + 1) for value in values] for key, values in dissimilarities.items()}
transformed_data = dissimilarities

# Prepare the plot
fig, ax = plt.subplots(figsize=(15, 6))

# Colors for the bars
colors = ['#FEF4B6','#CEF1DB', "#a8daf7"]

# Plotting the data
keys = list(transformed_data.keys())
values = np.array(list(transformed_data.values()))

bar_width = 0.1
indices = np.arange(len(keys))

intensities = ["low", "medium", "high"]

# Create bars for each value
for i in range(values.shape[1]):
    ax.bar(indices + i * bar_width, values[:, i], bar_width, label=f'intensity {intensities[i]}', color=colors[i], edgecolor='black')

# Labeling the graph
ax.set_xlabel('Effects')
ax.set_ylabel('Log-transformed values')
ax.set_title('Log-transformed dissimilarity values for each effect')
ax.set_xticks(indices + bar_width * 1.5)  # Adjust for centering
ax.set_xticklabels(keys)
ax.legend()

# Show the plot
plt.show()
# Out:
# Reverb applied, intensity: low
# Dissimilarity: 0.4645559018268995
# Reverb applied, intensity: medium
# Dissimilarity: 0.5567998729900829
# Reverb applied, intensity: high
# Dissimilarity: 0.711209751620693
# Chorus applied, intensity: low
# Dissimilarity: 2.011668309510395
# Chorus applied, intensity: medium
# Dissimilarity: 1.6868263561776426
# Chorus applied, intensity: high
# Dissimilarity: 1.8396648275656866
# Distortion applied, intensity: low
# Dissimilarity: 0.432403593987819
# Distortion applied, intensity: medium
# Dissimilarity: 0.9964504064787166
# Distortion applied, intensity: high
# Dissimilarity: 1.0881410128363218
# Delay applied, intensity: low
# Dissimilarity: 0.9915878289520066
# Delay applied, intensity: medium
# Dissimilarity: 2.35600855756335
# Delay applied, intensity: high
# Dissimilarity: 3.1202527924173196
# Phaser applied, intensity: low
# Dissimilarity: 1.229182209678743
# Phaser applied, intensity: medium
# Dissimilarity: 1.37651024400248
# Phaser applied, intensity: high
# Dissimilarity: 1.4079569450520388
# Compressor applied, intensity: low
# Dissimilarity: 2.8487048707149047
# Compressor applied, intensity: medium
# Dissimilarity: 2.5072321884319786
# Compressor applied, intensity: high
# Dissimilarity: 2.075411309066419
# Gain applied, intensity: low
# Dissimilarity: 0.30756997950659903
# Gain applied, intensity: medium
# Dissimilarity: 1.221008648781698
# Gain applied, intensity: high
# Dissimilarity: 1.939812078851431
# Clipping applied, intensity: low
# Dissimilarity: 0.36585806738119125
# Clipping applied, intensity: medium
# Dissimilarity: 1.2553399751651302
# Clipping applied, intensity: high
# Dissimilarity: 1.8488137812571899

# %%
# Sample constellation maps
#M_A = np.array([(11, 22), (23, 31), (14, 15)])
#M_B = np.array([(1, 2), (2, 3), (4, 5), (5, 6), (6, 7), (7, 8)])      

peak_data_filtered_no_effect = constellation_map_builder('audios/G4_guitar_Phaser_low.mp3')
peak_data_filtered_with_effect = constellation_map_builder('audios/G4_guitar_Phaser_high.mp3')

if len(peak_data_filtered_no_effect) < len(peak_data_filtered_with_effect):
    M_A = peak_data_filtered_no_effect
    M_B = peak_data_filtered_with_effect
else:
    M_A = peak_data_filtered_with_effect
    M_B = peak_data_filtered_no_effect



# Running FOCM algorithm
n_clusters = len(M_B)
U, V = focm(M_A, M_B, n_clusters)

dissimilarity = calculate_dissimilarity(M_A, M_B, U)
print(f"Dissimilarity: {dissimilarity}")
# Out:
# Dissimilarity: 2.0454358896173788

# %%
import numpy as np

def initialize_membership_matrix(n, c):
    # Initialize a random partition matrix U with constraints
    U = np.random.rand(n, c)
    U = U / np.sum(U, axis=1, keepdims=True)
    return U

def compute_centroids(X, U, c, lambda_exp):
    # Calculate the centroids for each cluster
    n_features = X.shape[1]
    centroids = np.zeros((c, n_features))
    for j in range(c):
        numerator = np.sum((U[:, j] ** lambda_exp)[:, np.newaxis] * X, axis=0)
        denominator = np.sum(U[:, j] ** lambda_exp)
        centroids[j, :] = numerator / denominator
    return centroids

def update_membership_matrix(X, centroids, c, lambda_exp):
    # Update the membership matrix U
    n = X.shape[0]
    U_new = np.zeros((n, c))
    for i in range(n):
        for j in range(c):
            sum_terms = np.sum([(np.linalg.norm(X[i] - centroids[j]) / np.linalg.norm(X[i] - centroids[k])) ** (2 / (lambda_exp - 1)) for k in range(c)])
            U_new[i, j] = 1 / sum_terms
    return U_new

def fuzzy_c_means(X, c, lambda_exp=2, max_iter=20, tolerance=1e-4):
    # Fuzzy C-Means Clustering Algorithm
    n = X.shape[0]
    U = initialize_membership_matrix(n, c)
    
    for _ in range(max_iter):
        print(f"Iteration {_}")
        centroids = compute_centroids(X, U, c, lambda_exp)
        U_new = update_membership_matrix(X, centroids, c, lambda_exp)
        
        print(f"Difference between U_new and U: {np.linalg.norm(U_new - U)}")
        # Check for convergence
        if np.linalg.norm(U_new - U) < tolerance:
            break
        U = U_new
    
    return U, centroids

def calculate_dissimilarity(TA, TB, U):
    # Calculate the dissimilarity based on FCM
    n, m = len(TA), len(TB)
    dissimilarity = 0
    for i in range(n):
        for j in range(m):
            dissimilarity += U[i, j] * np.linalg.norm(TA[i] - TB[j])
    return dissimilarity / (n * m)


effects = ['Reverb', 'Chorus', "Distortion", 'Delay', 'Phaser', 'Compressor', 'Gain', "Clipping"]
intensities = ["low", "medium", "high"]

# Initialize dissimilarities as a list of lists
dissimilarities = {effect: [] for effect in effects}

file_path = 'audios/scala.mp3'
threshold = 3

for effect in effects:
    for intensity in intensities: 
        print(f"{effect} applied, intensity: {intensity}")
        file_tested = 'audios/scala_' + str(effect) + "_" + str(intensity) + ".mp3"

        TA = np.array(z_score_peaks_calculation(file_path, threshold))  # Points from audio A
        TB = np.array(z_score_peaks_calculation(file_tested, threshold))  # Points from audio B
        
        # Randomly sample points from TA and TB
        num_sampled_TA = len(TA)
        num_sampled_TB = len(TB)
        
        sampled_TA = TA[np.random.choice(len(TA), num_sampled_TA, replace=False)]
        sampled_TB = TB[np.random.choice(len(TB), num_sampled_TB, replace=False)]
        # Choose the number of clusters based on the smaller set
        c = min(len(TA), len(TB))
        
        print(f"len(TA): {len(TA)}\n len(TB): {len(TB)}\n len(sampled_TA): {len(sampled_TA)}\n len(sampled_TB): {len(sampled_TB)}")

        # Determine which set is larger and perform clustering
        if len(sampled_TA) >= len(sampled_TB):
            # Cluster TA using TB as initial centroids
            U, centroids = fuzzy_c_means(sampled_TA, c)
            # Calculate the dissimilarity: TA is the larger set, TB is the centroids set
            dissimilarity = calculate_dissimilarity(sampled_TA, sampled_TB, U)
        else:
            # Cluster TB using TA as initial centroids
            U, centroids = fuzzy_c_means(sampled_TB, c)
            # Calculate the dissimilarity: TB is the larger set, TA is the centroids set
            dissimilarity = calculate_dissimilarity(sampled_TB, sampled_TA, U)
        
        dissimilarities[effect].append(dissimilarity)
        print(f"Dissimilarity: {dissimilarity}")
    

# Apply logarithmic transformation to the data
#transformed_data = {key: [np.log10(value + 1) for value in values] for key, values in dissimilarities.items()}
transformed_data = dissimilarities

# Prepare the plot
fig, ax = plt.subplots(figsize=(15, 6))

# Colors for the bars
colors = ['#FEF4B6','#CEF1DB', "#a8daf7"]

# Plotting the data
keys = list(transformed_data.keys())
values = np.array(list(transformed_data.values()))

bar_width = 0.1
indices = np.arange(len(keys))

intensities = ["low", "medium", "high"]

# Create bars for each value
for i in range(values.shape[1]):
    ax.bar(indices + i * bar_width, values[:, i], bar_width, label=f'intensity {intensities[i]}', color=colors[i], edgecolor='black')

# Labeling the graph
ax.set_xlabel('Effects')
ax.set_ylabel('Log-transformed values')
ax.set_title('Log-transformed dissimilarity values for each effect')
ax.set_xticks(indices + bar_width * 1.5)  # Adjust for centering
ax.set_xticklabels(keys)
ax.legend()

# Show the plot
plt.show()
# Out:
# Reverb applied, intensity: low
# len(TA): 16
#  len(TB): 66
#  len(sampled_TA): 16
#  len(sampled_TB): 66
# Iteration 0
# Difference between U_new and U: 1.5816320105644737
# Iteration 1
# Difference between U_new and U: 1.7824595285466631
# Iteration 2
# Difference between U_new and U: 2.4614072463795327
# Iteration 3
# Difference between U_new and U: 2.639332194121587
# Iteration 4
# Difference between U_new and U: 2.702718137310181
# Iteration 5
# Difference between U_new and U: 1.651913835512597
# Iteration 6
# Difference between U_new and U: 1.348593127689728
# Iteration 7
# Difference between U_new and U: 1.5051448637749045
# Iteration 8
# Difference between U_new and U: 0.7357643364502657
# Iteration 9
# Difference between U_new and U: 0.4018423948313887
# Iteration 10
# Difference between U_new and U: 0.20008892825770053
# Iteration 11
# Difference between U_new and U: 0.11541210660412227
# Iteration 12
# Difference between U_new and U: 0.07852813896507908
# Iteration 13
# Difference between U_new and U: 0.057967289562971
# Iteration 14
# Difference between U_new and U: 0.04443064180999306
# Iteration 15
# Difference between U_new and U: 0.034809172757986166
# Iteration 16
# Difference between U_new and U: 0.027695671112841245
# Iteration 17
# Difference between U_new and U: 0.022298351331016195
# Iteration 18
# Difference between U_new and U: 0.01812121192158072
# Iteration 19
# Difference between U_new and U: 0.014836241739933411
# Dissimilarity: 7.853172899325449
# Reverb applied, intensity: medium
# len(TA): 16
#  len(TB): 75
#  len(sampled_TA): 16
#  len(sampled_TB): 75
# Iteration 0
# Difference between U_new and U: 1.6892017021546772
# Iteration 1
# Difference between U_new and U: 1.3905466738451515
# Iteration 2
# Difference between U_new and U: 1.9838369956857262
# Iteration 3
# Difference between U_new and U: 1.9454870779635856
# Iteration 4
# Difference between U_new and U: 2.050160301308629
# Iteration 5
# Difference between U_new and U: 1.646794465657364
# Iteration 6
# Difference between U_new and U: 1.523018230873055
# Iteration 7
# Difference between U_new and U: 1.1547575363590783
# Iteration 8
# Difference between U_new and U: 0.6565130698810103
# Iteration 9
# Difference between U_new and U: 0.452605115112639
# Iteration 10
# Difference between U_new and U: 0.4087532758382443
# Iteration 11
# Difference between U_new and U: 0.42560268916064364
# Iteration 12
# Difference between U_new and U: 0.3801067637542205
# Iteration 13
# Difference between U_new and U: 0.23350915372431258
# Iteration 14
# Difference between U_new and U: 0.17697990835506652
# Iteration 15
# Difference between U_new and U: 0.1769261549410038
# Iteration 16
# Difference between U_new and U: 0.20608615645055675
# Iteration 17
# Difference between U_new and U: 0.2740342829140047
# Iteration 18
# Difference between U_new and U: 0.38340728872300595
# Iteration 19
# Difference between U_new and U: 0.4475031660890803
# Dissimilarity: 7.614551107062028
# Reverb applied, intensity: high
# len(TA): 16
#  len(TB): 69
#  len(sampled_TA): 16
#  len(sampled_TB): 69
# Iteration 0
# Difference between U_new and U: 1.5780775490733179
# Iteration 1
# Difference between U_new and U: 1.3626891762464328
# Iteration 2
# Difference between U_new and U: 2.0602611890025826
# Iteration 3
# Difference between U_new and U: 2.164315954655146
# Iteration 4
# Difference between U_new and U: 2.1532287140119064
# Iteration 5
# Difference between U_new and U: 1.8787076109269565
# Iteration 6
# Difference between U_new and U: 1.4333535809294953
# Iteration 7
# Difference between U_new and U: 1.079322840847099
# Iteration 8
# Difference between U_new and U: 0.9347688052817668
# Iteration 9
# Difference between U_new and U: 0.74200524704106
# Iteration 10
# Difference between U_new and U: 0.6311939319882772
# Iteration 11
# Difference between U_new and U: 0.5186185175633359
# Iteration 12
# Difference between U_new and U: 0.40920633600759115
# Iteration 13
# Difference between U_new and U: 0.31753226448009536
# Iteration 14
# Difference between U_new and U: 0.25659402271198517
# Iteration 15
# Difference between U_new and U: 0.21781393617746822
# Iteration 16
# Difference between U_new and U: 0.17418401445204754
# Iteration 17
# Difference between U_new and U: 0.11978036853939855
# Iteration 18
# Difference between U_new and U: 0.0723583391289227
# Iteration 19
# Difference between U_new and U: 0.042116064562568487
# Dissimilarity: 9.585844188659744
# Chorus applied, intensity: low
# len(TA): 16
#  len(TB): 4
#  len(sampled_TA): 16
#  len(sampled_TB): 4
# Iteration 0
# Difference between U_new and U: 1.1316487164716347
# Iteration 1
# Difference between U_new and U: 1.3248630439912241
# Iteration 2
# Difference between U_new and U: 1.6574066189768735
# Iteration 3
# Difference between U_new and U: 1.7251240732896087
# Iteration 4
# Difference between U_new and U: 0.6508362518162997
# Iteration 5
# Difference between U_new and U: 0.3299244944615718
# Iteration 6
# Difference between U_new and U: 0.17166204092728762
# Iteration 7
# Difference between U_new and U: 0.09453974508088529
# Iteration 8
# Difference between U_new and U: 0.052953349120356256
# Iteration 9
# Difference between U_new and U: 0.029645840820837443
# Iteration 10
# Difference between U_new and U: 0.016541769810836042
# Iteration 11
# Difference between U_new and U: 0.009206075487379436
# Iteration 12
# Difference between U_new and U: 0.005115973247786739
# Iteration 13
# Difference between U_new and U: 0.0028411807601280577
# Iteration 14
# Difference between U_new and U: 0.0015776320132024004
# Iteration 15
# Difference between U_new and U: 0.0008761425694489974
# Iteration 16
# Difference between U_new and U: 0.0004867156427513347
# Iteration 17
# Difference between U_new and U: 0.00027048526711835174
# Iteration 18
# Difference between U_new and U: 0.0001503825299877305
# Iteration 19
# Difference between U_new and U: 8.364573447679144e-05
# Dissimilarity: 27.474168847602638
# Chorus applied, intensity: medium
# len(TA): 16
#  len(TB): 3
#  len(sampled_TA): 16
#  len(sampled_TB): 3
# Iteration 0
# Difference between U_new and U: 2.2094705747538517
# Iteration 1
# Difference between U_new and U: 1.3299813466376684
# Iteration 2
# Difference between U_new and U: 0.9531030708296635
# Iteration 3
# Difference between U_new and U: 0.5793431045717347
# Iteration 4
# Difference between U_new and U: 0.2961941597596032
# Iteration 5
# Difference between U_new and U: 0.1505475481922577
# Iteration 6
# Difference between U_new and U: 0.0780455741559506
# Iteration 7
# Difference between U_new and U: 0.041024564364503635
# Iteration 8
# Difference between U_new and U: 0.02174266436848654
# Iteration 9
# Difference between U_new and U: 0.011577167842307294
# Iteration 10
# Difference between U_new and U: 0.006180259494700564
# Iteration 11
# Difference between U_new and U: 0.0033038235746767155
# Iteration 12
# Difference between U_new and U: 0.0017674737176649738
# Iteration 13
# Difference between U_new and U: 0.0009459396409296271
# Iteration 14
# Difference between U_new and U: 0.0005063686087651829
# Iteration 15
# Difference between U_new and U: 0.0002710937460483749
# Iteration 16
# Difference between U_new and U: 0.00014514378126404717
# Iteration 17
# Difference between U_new and U: 7.771256977627474e-05
# Dissimilarity: 38.336119499507795
# Chorus applied, intensity: high
# len(TA): 16
#  len(TB): 19
#  len(sampled_TA): 16
#  len(sampled_TB): 19
# Iteration 0
# Difference between U_new and U: 0.9985686494254851
# Iteration 1
# Difference between U_new and U: 1.3675554711641789
# Iteration 2
# Difference between U_new and U: 1.922686104477426
# Iteration 3
# Difference between U_new and U: 1.5063746056684535
# Iteration 4
# Difference between U_new and U: 1.0415096047933108
# Iteration 5
# Difference between U_new and U: 0.7608500155244021
# Iteration 6
# Difference between U_new and U: 1.4342317421944453
# Iteration 7
# Difference between U_new and U: 0.716415327182346
# Iteration 8
# Difference between U_new and U: 0.5025984825889613
# Iteration 9
# Difference between U_new and U: 0.7631968575716227
# Iteration 10
# Difference between U_new and U: 0.2893208059963084
# Iteration 11
# Difference between U_new and U: 0.3368268202028952
# Iteration 12
# Difference between U_new and U: 0.04077041358655056
# Iteration 13
# Difference between U_new and U: 0.005509639997053315
# Iteration 14
# Difference between U_new and U: 0.002015490311238045
# Iteration 15
# Difference between U_new and U: 0.0008995523164180202
# Iteration 16
# Difference between U_new and U: 0.0004227299745736256
# Iteration 17
# Difference between U_new and U: 0.0002019013589143426
# Iteration 18
# Difference between U_new and U: 9.73266049891972e-05
# Dissimilarity: 7.569069692764495
# Distortion applied, intensity: low
# len(TA): 16
#  len(TB): 25
#  len(sampled_TA): 16
#  len(sampled_TB): 25
# Iteration 0
# Difference between U_new and U: 1.321362474069228
# Iteration 1
# Difference between U_new and U: 1.350991955922723
# Iteration 2
# Difference between U_new and U: 1.8302462962545878
# Iteration 3
# Difference between U_new and U: 1.9485053097268858
# Iteration 4
# Difference between U_new and U: 2.053803067248962
# Iteration 5
# Difference between U_new and U: 1.253599036716037
# Iteration 6
# Difference between U_new and U: 0.9316059319257046
# Iteration 7
# Difference between U_new and U: 0.653190183745669
# Iteration 8
# Difference between U_new and U: 0.40093084952060776
# Iteration 9
# Difference between U_new and U: 0.361832624410261
# Iteration 10
# Difference between U_new and U: 0.28461846990508
# Iteration 11
# Difference between U_new and U: 0.08524243952045536
# Iteration 12
# Difference between U_new and U: 0.04645821501020695
# Iteration 13
# Difference between U_new and U: 0.030471370407998483
# Iteration 14
# Difference between U_new and U: 0.01999708062471568
# Iteration 15
# Difference between U_new and U: 0.013094857105565906
# Iteration 16
# Difference between U_new and U: 0.008562675751586868
# Iteration 17
# Difference between U_new and U: 0.005595499438082613
# Iteration 18
# Difference between U_new and U: 0.003656993207883949
# Iteration 19
# Difference between U_new and U: 0.002391996680036384
# Dissimilarity: 7.7742627215113576
# Distortion applied, intensity: medium
# len(TA): 16
#  len(TB): 19
#  len(sampled_TA): 16
#  len(sampled_TB): 19
# Iteration 0
# Difference between U_new and U: 1.0000473371565517
# Iteration 1
# Difference between U_new and U: 1.147292948106585
# Iteration 2
# Difference between U_new and U: 1.5808576422269771
# Iteration 3
# Difference between U_new and U: 1.465051023381378
# Iteration 4
# Difference between U_new and U: 0.9864383968419882
# Iteration 5
# Difference between U_new and U: 1.0701933483719295
# Iteration 6
# Difference between U_new and U: 0.7368418664998186
# Iteration 7
# Difference between U_new and U: 0.6203077179306321
# Iteration 8
# Difference between U_new and U: 0.2069169741692521
# Iteration 9
# Difference between U_new and U: 1.0600367833725426
# Iteration 10
# Difference between U_new and U: 0.4260249628407254
# Iteration 11
# Difference between U_new and U: 0.17327986659608596
# Iteration 12
# Difference between U_new and U: 0.0433179194921265
# Iteration 13
# Difference between U_new and U: 0.022176626047742815
# Iteration 14
# Difference between U_new and U: 0.012688858366565949
# Iteration 15
# Difference between U_new and U: 0.007536758952467946
# Iteration 16
# Difference between U_new and U: 0.0045796072436469085
# Iteration 17
# Difference between U_new and U: 0.002828685627281381
# Iteration 18
# Difference between U_new and U: 0.0017687044298160652
# Iteration 19
# Difference between U_new and U: 0.0011159516668377738
# Dissimilarity: 9.575081962594137
# Distortion applied, intensity: high
# len(TA): 16
#  len(TB): 37
#  len(sampled_TA): 16
#  len(sampled_TB): 37
# Iteration 0
# Difference between U_new and U: 1.2657824782386908
# Iteration 1
# Difference between U_new and U: 1.1941142741463153
# Iteration 2
# Difference between U_new and U: 1.1411405006724322
# Iteration 3
# Difference between U_new and U: 1.3169437117323768
# Iteration 4
# Difference between U_new and U: 1.2985149126605575
# Iteration 5
# Difference between U_new and U: 1.5485008499323434
# Iteration 6
# Difference between U_new and U: 1.2703830310349027
# Iteration 7
# Difference between U_new and U: 0.9168451496574331
# Iteration 8
# Difference between U_new and U: 0.3298374424367284
# Iteration 9
# Difference between U_new and U: 0.1984782956477742
# Iteration 10
# Difference between U_new and U: 0.16745147572434502
# Iteration 11
# Difference between U_new and U: 0.15555954490203017
# Iteration 12
# Difference between U_new and U: 0.14699945255229466
# Iteration 13
# Difference between U_new and U: 0.13575285487439626
# Iteration 14
# Difference between U_new and U: 0.12356537538621405
# Iteration 15
# Difference between U_new and U: 0.11571060596280011
# Iteration 16
# Difference between U_new and U: 0.10876407462467813
# Iteration 17
# Difference between U_new and U: 0.09083190962729562
# Iteration 18
# Difference between U_new and U: 0.06169794180755052
# Iteration 19
# Difference between U_new and U: 0.03528074751995992
# Dissimilarity: 9.360187792902709
# Delay applied, intensity: low
# len(TA): 16
#  len(TB): 3
#  len(sampled_TA): 16
#  len(sampled_TB): 3
# Iteration 0
# Difference between U_new and U: 2.1204896995704363
# Iteration 1
# Difference between U_new and U: 1.466710215787119
# Iteration 2
# Difference between U_new and U: 0.8009613125766104
# Iteration 3
# Difference between U_new and U: 0.5112877046825427
# Iteration 4
# Difference between U_new and U: 0.5090478317522575
# Iteration 5
# Difference between U_new and U: 0.3833302043310587
# Iteration 6
# Difference between U_new and U: 0.2200188799428429
# Iteration 7
# Difference between U_new and U: 0.11701018765969017
# Iteration 8
# Difference between U_new and U: 0.061696621050600677
# Iteration 9
# Difference between U_new and U: 0.03266319793900983
# Iteration 10
# Difference between U_new and U: 0.017368588657886763
# Iteration 11
# Difference between U_new and U: 0.009263176099899392
# Iteration 12
# Difference between U_new and U: 0.004949060056063428
# Iteration 13
# Difference between U_new and U: 0.002646782149593822
# Iteration 14
# Difference between U_new and U: 0.0014162863514873278
# Iteration 15
# Difference between U_new and U: 0.0007580752175691304
# Iteration 16
# Difference between U_new and U: 0.0004058283288781478
# Iteration 17
# Difference between U_new and U: 0.00021727470041675565
# Iteration 18
# Difference between U_new and U: 0.00011633101533799979
# Iteration 19
# Difference between U_new and U: 6.228626291436422e-05
# Dissimilarity: 26.214330752512126
# Delay applied, intensity: medium
# len(TA): 16
#  len(TB): 4
#  len(sampled_TA): 16
#  len(sampled_TB): 4
# Iteration 0
# Difference between U_new and U: 2.0637588458056295
# Iteration 1
# Difference between U_new and U: 1.2264381728229468
# Iteration 2
# Difference between U_new and U: 0.8786069469594193
# Iteration 3
# Difference between U_new and U: 1.078021042334996
# Iteration 4
# Difference between U_new and U: 0.7518436669008206
# Iteration 5
# Difference between U_new and U: 0.40976246274260575
# Iteration 6
# Difference between U_new and U: 0.22986363455810357
# Iteration 7
# Difference between U_new and U: 0.12960094779253295
# Iteration 8
# Difference between U_new and U: 0.07210841184398144
# Iteration 9
# Difference between U_new and U: 0.03975338173469915
# Iteration 10
# Difference between U_new and U: 0.021797845108494706
# Iteration 11
# Difference between U_new and U: 0.011916383296660204
# Iteration 12
# Difference between U_new and U: 0.006504356689168804
# Iteration 13
# Difference between U_new and U: 0.003547905619410352
# Iteration 14
# Difference between U_new and U: 0.0019349368639888804
# Iteration 15
# Difference between U_new and U: 0.0010553919149629894
# Iteration 16
# Difference between U_new and U: 0.00057581717677391
# Iteration 17
# Difference between U_new and U: 0.0003142832004653423
# Iteration 18
# Difference between U_new and U: 0.00017161243197074018
# Iteration 19
# Difference between U_new and U: 9.375266173010225e-05
# Dissimilarity: 27.71689619746916
# Delay applied, intensity: high
# len(TA): 16
#  len(TB): 15
#  len(sampled_TA): 16
#  len(sampled_TB): 15
# Iteration 0
# Difference between U_new and U: 1.0672302731862933
# Iteration 1
# Difference between U_new and U: 1.4165895813621092
# Iteration 2
# Difference between U_new and U: 1.5770294862194187
# Iteration 3
# Difference between U_new and U: 1.4905411217479634
# Iteration 4
# Difference between U_new and U: 0.9608033740357828
# Iteration 5
# Difference between U_new and U: 1.0358538806803224
# Iteration 6
# Difference between U_new and U: 1.0131589601969955
# Iteration 7
# Difference between U_new and U: 0.6117423277740044
# Iteration 8
# Difference between U_new and U: 0.8951689553815951
# Iteration 9
# Difference between U_new and U: 0.44029123378817375
# Iteration 10
# Difference between U_new and U: 1.1147036595622033
# Iteration 11
# Difference between U_new and U: 0.2358351846456693
# Iteration 12
# Difference between U_new and U: 0.3886911585332347
# Iteration 13
# Difference between U_new and U: 0.9305086906011939
# Iteration 14
# Difference between U_new and U: 0.41229975151650816
# Iteration 15
# Difference between U_new and U: 0.006542811684107053
# Iteration 16
# Difference between U_new and U: 0.0034908288699635748
# Iteration 17
# Difference between U_new and U: 0.002176481187724529
# Iteration 18
# Difference between U_new and U: 0.0013597152740252936
# Iteration 19
# Difference between U_new and U: 0.0008505248064938675
# Dissimilarity: 9.890620555166718
# Phaser applied, intensity: low
# len(TA): 16
#  len(TB): 40
#  len(sampled_TA): 16
#  len(sampled_TB): 40
# Iteration 0
# Difference between U_new and U: 1.214782177680096
# Iteration 1
# Difference between U_new and U: 1.500057947203357
# Iteration 2
# Difference between U_new and U: 1.5578209891403436
# Iteration 3
# Difference between U_new and U: 1.352895172383428
# Iteration 4
# Difference between U_new and U: 1.5720433952977018
# Iteration 5
# Difference between U_new and U: 1.4481873640252039
# Iteration 6
# Difference between U_new and U: 0.7086531678576103
# Iteration 7
# Difference between U_new and U: 0.34561720531545637
# Iteration 8
# Difference between U_new and U: 0.6507904610045473
# Iteration 9
# Difference between U_new and U: 0.5080975249350916
# Iteration 10
# Difference between U_new and U: 0.4420450988281829
# Iteration 11
# Difference between U_new and U: 0.2987601866109823
# Iteration 12
# Difference between U_new and U: 0.12468550818572445
# Iteration 13
# Difference between U_new and U: 0.07718517522432486
# Iteration 14
# Difference between U_new and U: 0.04962612360380657
# Iteration 15
# Difference between U_new and U: 0.03331860884929899
# Iteration 16
# Difference between U_new and U: 0.023751978931762865
# Iteration 17
# Difference between U_new and U: 0.018362708222630735
# Iteration 18
# Difference between U_new and U: 0.0157480870547072
# Iteration 19
# Difference between U_new and U: 0.015069954694723602
# Dissimilarity: 9.018753869229943
# Phaser applied, intensity: medium
# len(TA): 16
#  len(TB): 24
#  len(sampled_TA): 16
#  len(sampled_TB): 24
# Iteration 0
# Difference between U_new and U: 1.0905855550225723
# Iteration 1
# Difference between U_new and U: 1.2821135844073048
# Iteration 2
# Difference between U_new and U: 1.7740840844901087
# Iteration 3
# Difference between U_new and U: 1.804672528552409
# Iteration 4
# Difference between U_new and U: 1.389112213408658
# Iteration 5
# Difference between U_new and U: 0.907482394901038
# Iteration 6
# Difference between U_new and U: 0.9922818387461831
# Iteration 7
# Difference between U_new and U: 0.6522797840897346
# Iteration 8
# Difference between U_new and U: 0.1516120786279764
# Iteration 9
# Difference between U_new and U: 0.09280442568001519
# Iteration 10
# Difference between U_new and U: 0.04698864686776167
# Iteration 11
# Difference between U_new and U: 0.02476408876464686
# Iteration 12
# Difference between U_new and U: 0.016383024071626884
# Iteration 13
# Difference between U_new and U: 0.012647491530535205
# Iteration 14
# Difference between U_new and U: 0.010527495270440414
# Iteration 15
# Difference between U_new and U: 0.009453094201892099
# Iteration 16
# Difference between U_new and U: 0.00920126443842364
# Iteration 17
# Difference between U_new and U: 0.009534152689908619
# Iteration 18
# Difference between U_new and U: 0.010249637458768515
# Iteration 19
# Difference between U_new and U: 0.011219692900293305
# Dissimilarity: 8.565014508432188
# Phaser applied, intensity: high
# len(TA): 16
#  len(TB): 31
#  len(sampled_TA): 16
#  len(sampled_TB): 31
# Iteration 0
# Difference between U_new and U: 1.364722416763132
# Iteration 1
# Difference between U_new and U: 1.7160723757691616
# Iteration 2
# Difference between U_new and U: 2.1373590163067875
# Iteration 3
# Difference between U_new and U: 1.6090514437111105
# Iteration 4
# Difference between U_new and U: 1.29921979701924
# Iteration 5
# Difference between U_new and U: 0.815138833000103
# Iteration 6
# Difference between U_new and U: 1.3560811967869197
# Iteration 7
# Difference between U_new and U: 0.92234952401269
# Iteration 8
# Difference between U_new and U: 0.38218437417102774
# Iteration 9
# Difference between U_new and U: 0.21531512880419035
# Iteration 10
# Difference between U_new and U: 0.18518855060529923
# Iteration 11
# Difference between U_new and U: 0.20217551418646149
# Iteration 12
# Difference between U_new and U: 0.191762139265619
# Iteration 13
# Difference between U_new and U: 0.1274650696624941
# Iteration 14
# Difference between U_new and U: 0.06444912353459382
# Iteration 15
# Difference between U_new and U: 0.037732145868219304
# Iteration 16
# Difference between U_new and U: 0.032107247249023314
# Iteration 17
# Difference between U_new and U: 0.03244980622407487
# Iteration 18
# Difference between U_new and U: 0.03432174781795691
# Iteration 19
# Difference between U_new and U: 0.03661214947257808
# Dissimilarity: 9.336663015347582
# Compressor applied, intensity: low
# len(TA): 16
#  len(TB): 10
#  len(sampled_TA): 16
#  len(sampled_TB): 10
# Iteration 0
# Difference between U_new and U: 1.2447146516543532
# Iteration 1
# Difference between U_new and U: 1.6090109540231512
# Iteration 2
# Difference between U_new and U: 1.6559324778849929
# Iteration 3
# Difference between U_new and U: 1.0072644056362892
# Iteration 4
# Difference between U_new and U: 1.1930321486687558
# Iteration 5
# Difference between U_new and U: 0.815865448484091
# Iteration 6
# Difference between U_new and U: 0.9236795610775376
# Iteration 7
# Difference between U_new and U: 0.6342056885976733
# Iteration 8
# Difference between U_new and U: 1.093562566439344
# Iteration 9
# Difference between U_new and U: 0.3752407617539584
# Iteration 10
# Difference between U_new and U: 0.08903508564465788
# Iteration 11
# Difference between U_new and U: 0.04672456296424876
# Iteration 12
# Difference between U_new and U: 0.025982448773766913
# Iteration 13
# Difference between U_new and U: 0.01488552641514164
# Iteration 14
# Difference between U_new and U: 0.008700153050428712
# Iteration 15
# Difference between U_new and U: 0.0051471190779900046
# Iteration 16
# Difference between U_new and U: 0.003067267900404012
# Iteration 17
# Difference between U_new and U: 0.0018357766768812114
# Iteration 18
# Difference between U_new and U: 0.0011015718319957312
# Iteration 19
# Difference between U_new and U: 0.0006620328422851481
# Dissimilarity: 15.484252936049364
# Compressor applied, intensity: medium
# len(TA): 16
#  len(TB): 48
#  len(sampled_TA): 16
#  len(sampled_TB): 48
# Iteration 0
# Difference between U_new and U: 1.023121572062336
# Iteration 1
# Difference between U_new and U: 0.660673235663149
# Iteration 2
# Difference between U_new and U: 1.148909993725351
# Iteration 3
# Difference between U_new and U: 1.5255356519001568
# Iteration 4
# Difference between U_new and U: 1.2572893650758161
# Iteration 5
# Difference between U_new and U: 1.5406570753347135
# Iteration 6
# Difference between U_new and U: 1.511440602875121
# Iteration 7
# Difference between U_new and U: 1.502769393754798
# Iteration 8
# Difference between U_new and U: 0.8607149994592151
# Iteration 9
# Difference between U_new and U: 0.6034904233286503
# Iteration 10
# Difference between U_new and U: 0.44758954561824366
# Iteration 11
# Difference between U_new and U: 0.15699500537654035
# Iteration 12
# Difference between U_new and U: 0.10800273556800254
# Iteration 13
# Difference between U_new and U: 0.08143560540622864
# Iteration 14
# Difference between U_new and U: 0.0650892395287018
# Iteration 15
# Difference between U_new and U: 0.05522009126241025
# Iteration 16
# Difference between U_new and U: 0.05070493599468233
# Iteration 17
# Difference between U_new and U: 0.050807014153529347
# Iteration 18
# Difference between U_new and U: 0.054683943370184
# Iteration 19
# Difference between U_new and U: 0.06138902718429111
# Dissimilarity: 9.134271546459297
# Compressor applied, intensity: high
# len(TA): 16
#  len(TB): 120
#  len(sampled_TA): 16
#  len(sampled_TB): 120
# Iteration 0
# Difference between U_new and U: 1.8905627222889918
# Iteration 1
# Difference between U_new and U: 1.8949731714398772
# Iteration 2
# Difference between U_new and U: 2.4429121832081364
# Iteration 3
# Difference between U_new and U: 2.670878717126072
# Iteration 4
# Difference between U_new and U: 2.08992083099459
# Iteration 5
# Difference between U_new and U: 2.1942645712345716
# Iteration 6
# Difference between U_new and U: 1.6244042391446296
# Iteration 7
# Difference between U_new and U: 1.1406393318340566
# Iteration 8
# Difference between U_new and U: 0.8899046536644444
# Iteration 9
# Difference between U_new and U: 0.5604512975978226
# Iteration 10
# Difference between U_new and U: 0.36661829818289365
# Iteration 11
# Difference between U_new and U: 0.31562168828318676
# Iteration 12
# Difference between U_new and U: 0.2978881394790009
# Iteration 13
# Difference between U_new and U: 0.2946605941347839
# Iteration 14
# Difference between U_new and U: 0.3008748424893285
# Iteration 15
# Difference between U_new and U: 0.3117725262025047
# Iteration 16
# Difference between U_new and U: 0.3200212975177464
# Iteration 17
# Difference between U_new and U: 0.31737317342464233
# Iteration 18
# Difference between U_new and U: 0.30020309957541985
# Iteration 19
# Difference between U_new and U: 0.2698016024343721
# Dissimilarity: 9.730950726421831
# Gain applied, intensity: low
# len(TA): 16
#  len(TB): 34
#  len(sampled_TA): 16
#  len(sampled_TB): 34
# Iteration 0
# Difference between U_new and U: 1.2305063089658939
# Iteration 1
# Difference between U_new and U: 1.54279481655294
# Iteration 2
# Difference between U_new and U: 2.2715508417915213
# Iteration 3
# Difference between U_new and U: 1.5634848435975055
# Iteration 4
# Difference between U_new and U: 1.5229535455780692
# Iteration 5
# Difference between U_new and U: 1.6978438540128136
# Iteration 6
# Difference between U_new and U: 1.1701719950892762
# Iteration 7
# Difference between U_new and U: 1.092096360556652
# Iteration 8
# Difference between U_new and U: 0.5189054107277542
# Iteration 9
# Difference between U_new and U: 0.4908000532788224
# Iteration 10
# Difference between U_new and U: 0.5942344280769952
# Iteration 11
# Difference between U_new and U: 0.416297411418039
# Iteration 12
# Difference between U_new and U: 0.26869643598161
# Iteration 13
# Difference between U_new and U: 0.19660450198714255
# Iteration 14
# Difference between U_new and U: 0.16053262651663572
# Iteration 15
# Difference between U_new and U: 0.14786083509543205
# Iteration 16
# Difference between U_new and U: 0.14460644659673255
# Iteration 17
# Difference between U_new and U: 0.137490144274507
# Iteration 18
# Difference between U_new and U: 0.11973227329677547
# Iteration 19
# Difference between U_new and U: 0.09465074651884585
# Dissimilarity: 8.393151311232643
# Gain applied, intensity: medium
# len(TA): 16
#  len(TB): 51
#  len(sampled_TA): 16
#  len(sampled_TB): 51
# Iteration 0
# Difference between U_new and U: 1.13095371422556
# Iteration 1
# Difference between U_new and U: 0.7692447005681832
# Iteration 2
# Difference between U_new and U: 1.1343966612037
# Iteration 3
# Difference between U_new and U: 1.6085368617800604
# Iteration 4
# Difference between U_new and U: 1.6776758994058927
# Iteration 5
# Difference between U_new and U: 1.5732656122983895
# Iteration 6
# Difference between U_new and U: 1.614300199215365
# Iteration 7
# Difference between U_new and U: 0.8869220613368495
# Iteration 8
# Difference between U_new and U: 0.4785387984060236
# Iteration 9
# Difference between U_new and U: 0.6547264679491368
# Iteration 10
# Difference between U_new and U: 0.5815136963181363
# Iteration 11
# Difference between U_new and U: 0.20824724498718278
# Iteration 12
# Difference between U_new and U: 0.18082800777123142
# Iteration 13
# Difference between U_new and U: 0.24078065159064066
# Iteration 14
# Difference between U_new and U: 0.2555756246449164
# Iteration 15
# Difference between U_new and U: 0.11670226363337678
# Iteration 16
# Difference between U_new and U: 0.055296742385712305
# Iteration 17
# Difference between U_new and U: 0.051402457624287454
# Iteration 18
# Difference between U_new and U: 0.056816884217100475
# Iteration 19
# Difference between U_new and U: 0.06604706623686295
# Dissimilarity: 10.326026033972303
# Gain applied, intensity: high
# len(TA): 16
#  len(TB): 57
#  len(sampled_TA): 16
#  len(sampled_TB): 57
# Iteration 0
# Difference between U_new and U: 1.6517133107300703
# Iteration 1
# Difference between U_new and U: 1.0919044272154832
# Iteration 2
# Difference between U_new and U: 1.70582897590767
# Iteration 3
# Difference between U_new and U: 1.98241000121253
# Iteration 4
# Difference between U_new and U: 1.97019748058157
# Iteration 5
# Difference between U_new and U: 1.4546539037275203
# Iteration 6
# Difference between U_new and U: 1.0110727770487382
# Iteration 7
# Difference between U_new and U: 0.6040777447428181
# Iteration 8
# Difference between U_new and U: 0.43680803941313384
# Iteration 9
# Difference between U_new and U: 0.3790905757237592
# Iteration 10
# Difference between U_new and U: 0.47826277336487955
# Iteration 11
# Difference between U_new and U: 0.6105898284250794
# Iteration 12
# Difference between U_new and U: 0.4117022770269586
# Iteration 13
# Difference between U_new and U: 0.3055219745224177
# Iteration 14
# Difference between U_new and U: 0.24361423778405422
# Iteration 15
# Difference between U_new and U: 0.18478178152872243
# Iteration 16
# Difference between U_new and U: 0.13387737374903125
# Iteration 17
# Difference between U_new and U: 0.09700137347021477
# Iteration 18
# Difference between U_new and U: 0.07466358520016991
# Iteration 19
# Difference between U_new and U: 0.06283971188152551
# Dissimilarity: 9.187669694714433
# Clipping applied, intensity: low
# len(TA): 16
#  len(TB): 35
#  len(sampled_TA): 16
#  len(sampled_TB): 35
# Iteration 0
# Difference between U_new and U: 1.2762935914990203
# Iteration 1
# Difference between U_new and U: 1.3006080313495676
# Iteration 2
# Difference between U_new and U: 2.1768483505974174
# Iteration 3
# Difference between U_new and U: 1.4485708748106751
# Iteration 4
# Difference between U_new and U: 1.43191016788465
# Iteration 5
# Difference between U_new and U: 1.1736555395003647
# Iteration 6
# Difference between U_new and U: 0.8079877957835361
# Iteration 7
# Difference between U_new and U: 0.391517159949971
# Iteration 8
# Difference between U_new and U: 0.5006362818887842
# Iteration 9
# Difference between U_new and U: 0.4547132096640635
# Iteration 10
# Difference between U_new and U: 0.11971911735377035
# Iteration 11
# Difference between U_new and U: 0.0802060831587494
# Iteration 12
# Difference between U_new and U: 0.06223023380302839
# Iteration 13
# Difference between U_new and U: 0.04848586906986875
# Iteration 14
# Difference between U_new and U: 0.03669028977350356
# Iteration 15
# Difference between U_new and U: 0.026749097181383838
# Iteration 16
# Difference between U_new and U: 0.018885322157355784
# Iteration 17
# Difference between U_new and U: 0.013026757339562454
# Iteration 18
# Difference between U_new and U: 0.008847905741005963
# Iteration 19
# Difference between U_new and U: 0.005950696158414753
# Dissimilarity: 8.281281151919908
# Clipping applied, intensity: medium
# len(TA): 16
#  len(TB): 39
#  len(sampled_TA): 16
#  len(sampled_TB): 39
# Iteration 0
# Difference between U_new and U: 1.5972280908763643
# Iteration 1
# Difference between U_new and U: 1.0522152681069528
# Iteration 2
# Difference between U_new and U: 1.2358244518791601
# Iteration 3
# Difference between U_new and U: 1.5768539897303588
# Iteration 4
# Difference between U_new and U: 1.3228425640979016
# Iteration 5
# Difference between U_new and U: 1.2347108753430733
# Iteration 6
# Difference between U_new and U: 1.4033438562527625
# Iteration 7
# Difference between U_new and U: 0.9653849692562099
# Iteration 8
# Difference between U_new and U: 0.8148828662491744
# Iteration 9
# Difference between U_new and U: 0.6209505916213663
# Iteration 10
# Difference between U_new and U: 0.31987700233560723
# Iteration 11
# Difference between U_new and U: 0.1936186187171456
# Iteration 12
# Difference between U_new and U: 0.20321088803850354
# Iteration 13
# Difference between U_new and U: 0.21231729076911698
# Iteration 14
# Difference between U_new and U: 0.22232826836739852
# Iteration 15
# Difference between U_new and U: 0.24843198059322996
# Iteration 16
# Difference between U_new and U: 0.2650539325637776
# Iteration 17
# Difference between U_new and U: 0.19942973592358076
# Iteration 18
# Difference between U_new and U: 0.10449588654419392
# Iteration 19
# Difference between U_new and U: 0.06017011824004241
# Dissimilarity: 9.265154364559269
# Clipping applied, intensity: high
# len(TA): 16
#  len(TB): 60
#  len(sampled_TA): 16
#  len(sampled_TB): 60
# Iteration 0
# Difference between U_new and U: 1.548974376868406
# Iteration 1
# Difference between U_new and U: 1.1758841136840001
# Iteration 2
# Difference between U_new and U: 1.603510192749876
# Iteration 3
# Difference between U_new and U: 1.9077840192914572
# Iteration 4
# Difference between U_new and U: 1.322454485762366
# Iteration 5
# Difference between U_new and U: 1.9775911365328551
# Iteration 6
# Difference between U_new and U: 1.4111197092644328
# Iteration 7
# Difference between U_new and U: 0.8746753145516774
# Iteration 8
# Difference between U_new and U: 0.7241158945535768
# Iteration 9
# Difference between U_new and U: 0.5775792841794004
# Iteration 10
# Difference between U_new and U: 0.6598335950925537
# Iteration 11
# Difference between U_new and U: 0.8150993253300974
# Iteration 12
# Difference between U_new and U: 0.9188850632623231
# Iteration 13
# Difference between U_new and U: 0.6390344548432391
# Iteration 14
# Difference between U_new and U: 0.539643900004366
# Iteration 15
# Difference between U_new and U: 0.6703883372526118
# Iteration 16
# Difference between U_new and U: 0.4330881115625954
# Iteration 17
# Difference between U_new and U: 0.22613713343461567
# Iteration 18
# Difference between U_new and U: 0.13504597498854246
# Iteration 19
# Difference between U_new and U: 0.09970851043343665
# Dissimilarity: 10.109080855831454

# %%
# Example usage
TA = np.array(z_score_peaks_calculation('audios/G4_guitar.mp3', 3))  # Points from audio A
TB = np.array(z_score_peaks_calculation('audios/G4_guitar_Reverb_high.mp3', 3))  # Points from audio B
# Choose the number of clusters based on the smaller set
c = len(TA)

# Determine which set is larger and perform clustering
if len(TA) >= len(TB):
    # Cluster TA using TB as initial centroids
    U, centroids = fuzzy_c_means(TA, c)
    # Calculate the dissimilarity: TA is the larger set, TB is the centroids set
    dissimilarity = calculate_dissimilarity(TA, TB, U)
else:
    # Cluster TB using TA as initial centroids
    U, centroids = fuzzy_c_means(TB, c)
    # Calculate the dissimilarity: TB is the larger set, TA is the centroids set
    dissimilarity = calculate_dissimilarity(TB, TA, U)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 15
#      12     dissimilarity = calculate_dissimilarity(TA, TB, U)
#      13 else:
#      14     # Cluster TB using TA as initial centroids
# ---> 15     U, centroids = fuzzy_c_means(TB, c)
#      16     # Calculate the dissimilarity: TB is the larger set, TA is the centroids set
#      17     dissimilarity = calculate_dissimilarity(TB, TA, U)
#
# Cell In[49], line 37, in fuzzy_c_means(X, c, lambda_exp, max_iter, tolerance)
#      34 for _ in range(max_iter):
#      35     #print(f"Iteration {_}")
#      36     centroids = compute_centroids(X, U, c, lambda_exp)
# ---> 37     U_new = update_membership_matrix(X, centroids, c, lambda_exp)
#      39     #print(f"Difference between U_new and U: {np.linalg.norm(U_new - U)}")
#      40     # Check for convergence
#      41     if np.linalg.norm(U_new - U) < tolerance:
#
# Cell In[49], line 25, in update_membership_matrix(X, centroids, c, lambda_exp)
#      23 for i in range(n):
#      24     for j in range(c):
# ---> 25         sum_terms = np.sum([(np.linalg.norm(X[i] - centroids[j]) / np.linalg.norm(X[i] - centroids[k])) ** (2 / (lambda_exp - 1)) for k in range(c)])
#      26         U_new[i, j] = 1 / sum_terms
#      27 return U_new
#
# File c:\Users\pelli\miniconda3\Lib\site-packages\numpy\linalg\linalg.py:2379, in _norm_dispatcher(x, ord, axis, keepdims)
#    2375     result = op(svd(y, compute_uv=False), axis=-1)
#    2376     return result
# -> 2379 def _norm_dispatcher(x, ord=None, axis=None, keepdims=None):
#    2380     return (x,)
#    2383 @array_function_dispatch(_norm_dispatcher)
#    2384 def norm(x, ord=None, axis=None, keepdims=False):
#
# KeyboardInterrupt:
